# %% [markdown]
# # 第一讲 生成式AI是什么？
#
# Generative AI:让机器产生负责又有结构的物件（如：文章、影像、语音）
#
# 什么不是生成式AI？
# - 分类：从有限的选择中做选择（如：垃圾邮件侦测、猫狗分类器）
#
# ![机器学习](../img/1_1.png)
# 机器学习：机器自动从资料找一个函式
#
# ![生成式人工智能关系图](../img/1_2.png)
